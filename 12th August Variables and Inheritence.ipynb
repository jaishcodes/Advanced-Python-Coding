# %%
class Empl:
    no_employees = 0
    raise_amount = 1.04
    
    def __init__(self, first, lst, pay):
        self.first = first
        self.last = last
        self.pay = pay
        
        Empl.no_of_employees += 1
        def apply_raise(self):
            self.pay = int(self.pay * Empl.raise_amount)

# %% [markdown]
# Class Varibles

# %%
print(Empl.no_of_employees)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(Empl.no_of_employees)
#
# AttributeError: type object 'Empl' has no attribute 'no_of_employees'
